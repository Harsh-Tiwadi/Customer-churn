# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv("../data/customer churn/Customer_Info.csv")
df2 = pd.read_csv("../data/customer churn/Location_Data.csv")
df3 = pd.read_csv("../data/customer churn/Online_Services.csv")
df4 = pd.read_csv("../data/customer churn/Payment_Info.csv")
df5 = pd.read_csv("../data/customer churn/Service_Options.csv")#data/customer churn/Service_Options.csv
df6 = pd.read_csv("../data/customer churn/Status_Analysis.csv")

# %%
# Reset the index of each DataFrame
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)
df3 = df3.reset_index(drop=True)
df4 = df4.reset_index(drop=True)
df5 = df5.reset_index(drop=True)
df6 = df6.reset_index(drop=True)

# %%
merged_df = pd.concat([df1,df2,df3,df4,df5,df6], axis=1)

# %%
merged_df.shape
# Out:
# (7043, 58)

# %%
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]
merged_df.shape
# Out:
# (7043, 51)

# %%
merged_df.head()
# Out:
#   customer_id  gender  age under_30 senior_citizen partner dependents  \
# 0  0002-ORFBO  Female   37       No             No     Yes         No
# 1  0003-MKNFE    Male   46       No             No      No         No
# 2  0004-TLHLJ    Male   50       No             No      No         No
# 3  0011-IGKFF    Male   78       No            Yes     Yes         No
# 4  0013-EXCHZ  Female   75       No            Yes     Yes         No
#
#    number_of_dependents married        country       state          city  \
# 0                     0     Yes  United States  California  Frazier Park
# 1                     0      No  United States  California      Glendale
# 2                     0      No  United States  California    Costa Mesa
# 3                     0     Yes  United States  California      Martinez
# 4                     0     Yes  United States  California     Camarillo
#
#    zip_code  total_population   latitude   longitude phone_service  \
# ...

# %%
merged_df.to_parquet('../data/customer churn/merged_data/merged_data.parquet') # uncoment this to save
print('merged data saved!!!!')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 merged_df.to_parquet('../data/customer churn/merged_data/merged_data.parquet') # uncoment this to save
#       2 print('merged data saved!!!!')
#
# File ~/lab/lib/python3.11/site-packages/pandas/core/frame.py:2889, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2802 """
#    2803 Write a DataFrame to the binary parquet format.
#    2804
#    (...)
#    2885 >>> content = f.read()
#    2886 """
#    2887 from pandas.io.parquet import to_parquet
# -> 2889 return to_parquet(
#    2890     self,
#    2891     path,
#    2892     engine,
#    2893     compression=compression,
#    2894     index=index,
#    2895     partition_cols=partition_cols,
#    2896     storage_options=storage_options,
#    2897     **kwargs,
#    2898 )
#
# ...
